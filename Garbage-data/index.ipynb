# %%
import pandas as pd
data = pd.read_csv('Dataset//Garbaage-data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked   Credit-Card    Phone-No  \
# 0      0         A/5 21171   7.2500        S  441-660-7179 -6826740597
# 1      0          PC 17599  71.2833        C  121-779-9592 -8907531072
# ...

# %%
data.set_index("PassengerId", inplace=True)
data.head()
# Out:
#              Unnamed: 0  Survived  Pclass  \
# PassengerId
# 1                     0         0       3
# 2                     1         1       1
# 3                     2         1       3
# 4                     3         1       1
# 5                     4         0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Embarked   Credit-Card  \
# PassengerId
# 1                1      0         A/5 21171   7.2500        S  441-660-7179
# ...

# %%
#drop column
data.drop(columns=["Unnamed: 0"], inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
#  11  Credit-Card  891 non-null    object
#  12  Phone-No     891 non-null    int64
#  13  Address      891 non-null    object
# dtypes: float64(2), int64(6), object(6)
# memory usage: 97.6+ KB

# %%
d1=data.groupby('Survived')
d1.size()
data.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0            1       no       3
# 1            2       no       1
# 2            3       no       3
# 3            4       no       1
# 4            5       no       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked   Credit-Card    Phone-No  \
# 0      0         A/5 21171   7.2500        S  441-660-7179 -6826740597
# 1      0          PC 17599  71.2833        C  121-779-9592 -8907531072
# 2      0  STON/O2. 3101282   7.9250        S  111-457-6467 -1379047088
# ...

# %%
# #lmmda 



# data.groupby('Survived').size()
data["Survived"] = data["Survived"].apply(lambda x: 'yes' if int(x) == 1 else 'no')
data.head()
# Out:
#    Unnamed: 0  PassengerId Survived  Pclass  \
# 0           0            1       no       3
# 1           1            2      yes       1
# 2           2            3      yes       3
# 3           3            4      yes       1
# 4           4            5       no       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked   Credit-Card    Phone-No  \
# 0      0         A/5 21171   7.2500        S  441-660-7179 -6826740597
# 1      0          PC 17599  71.2833        C  121-779-9592 -8907531072
# ...

# %%
for x in data.index:
   if data.loc[x, "Survived"] == 'no':
       data.drop(x, inplace=True)

# %%
# Out:
# (342, 15)
