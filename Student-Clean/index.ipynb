# %%
import pandas as pd
data = pd.read_csv('Dataset//Students.csv')

# %%
data.shape
# Out:
# (498, 56)

# %%
data.head()
# Out:
#              Timestamp  Gender  \
# 0  11/28/2024 21:06:43    MALE
# 1  11/28/2024 21:25:49  FEMALE
# 2  11/28/2024 21:31:27     NaN
# 3  11/28/2024 21:34:55    MALE
# 4  11/28/2024 21:36:11  FEMALE
#
#   Which subjects do you enjoy studying the most?   \
# 0                         Physics Chemistry Maths
# 1                         English and mathematics
# 2                            Maths and languages
# 3                                     Accountancy
# 4                                        Science
#
#   Which subjects do you find most challenging?       Aspire To Be  \
# 0                                      History      Entrepreneur
# 1                                  Mathematics           A doctor
# 2                               None as of now  Maybe an engineer
# 3                                     Science             Artist
# 4                                          Sst      Cardiologist
#
# ...

# %%
#Drop by name
# data.drop(columns=["#NAME?"], inplace=True)


# Drop column by index (say the 2nd column, index = 1)

data.drop(data.columns[12], axis=1, inplace=True)

# %%
#rename column on the basis of index
#data.rename(columns={data.columns[1]: 'Class'}, inplace=True)

#data.rename(columns={data.columns[3]: 'Favorite-Sub'}, inplace=True)
data.rename(columns={data.columns[10]: 'Inspire'}, inplace=True)

# %%
data.shape
# Out:
# (498, 14)

# %%
data.head()
# Out:
#              Timestamp  Gender             Favorite-Sub  Toughest-Sub  \
# 0  11/28/2024 21:06:43    MALE  Physics Chemistry Maths       History
# 3  11/28/2024 21:34:55    MALE              Accountancy      Science
# 4  11/28/2024 21:36:11  FEMALE                 Science            Sst
# 5  11/28/2024 21:50:04    MALE          Social Studies   Mathematics
# 6  11/28/2024 21:54:21    MALE                  Science          Math
#
#     Aspire To Be               Skill        Soft-Skill Activities  \
# 0  Entrepreneur          programming   Problem solving    Cycling
# 3        Artist   Graphic designing     Communication     Coding
# 4  Cardiologist         Programming   Problem solving     Dancing
# 5      Cricketer            Writing          Teamwork     Sports
# 6         Doctor         Programing           Teamwork     Sports
#
#            Reading                     Hobbies  \
# 0           Others            Mountain cycling
# 3  Science fiction                  Gardening
# ...

# %%
#rename values in a column gender
data['Gender'] = data['Gender'].replace({'MALE': 'M', 'FEMALE': 'F'})

# %%
# drop row which have NaN in gender column

data = data.dropna(subset=['Inspire'])

# %%
data.shape
# Out:
# (375, 45)

# %%
pd.set_option("display.max_columns",None)

# %%
pd.set_option("display.max_columns", None)
print(data)   # ⚠️ careful with big CSVs!
      # works in any environment
# Out:
#                Timestamp  Gender  \
# 0    11/28/2024 21:06:43    MALE
# 3    11/28/2024 21:34:55    MALE
# 4    11/28/2024 21:36:11  FEMALE
# 5    11/28/2024 21:50:04    MALE
# 6    11/28/2024 21:54:21    MALE
# 7    11/28/2024 21:56:11  FEMALE
# 8    11/28/2024 21:58:26    MALE
# 9    11/28/2024 21:59:18  FEMALE
# 10   11/28/2024 22:07:16    MALE
# 11   11/28/2024 22:10:34  FEMALE
# 12   11/28/2024 22:16:12  FEMALE
# 14   11/28/2024 22:25:08  FEMALE
# 15   11/28/2024 22:25:23    MALE
# 16   11/28/2024 22:27:48  FEMALE
# 18   11/28/2024 23:01:21  FEMALE
# 19   11/28/2024 23:03:18  FEMALE
# 20    11/29/2024 0:02:34  FEMALE
# 21    11/29/2024 0:15:24    MALE
# 22    11/29/2024 0:22:25  FEMALE
# 23    11/29/2024 8:23:40  FEMALE
# 24    11/29/2024 8:42:42  FEMALE
# 28   11/29/2024 10:28:37    MALE
# 32   11/29/2024 10:41:52  FEMALE
# 43   11/29/2024 11:39:15    MALE
# 45   11/29/2024 11:40:07  FEMALE
# 46   11/29/2024 11:48:21  FEMALE
# 52   11/29/2024 12:06:35  FEMALE
# ...
