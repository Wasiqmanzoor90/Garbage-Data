# %%
import pandas as pd

#import csv file
df = pd.read_csv("Dataset//population.csv")

# %%
df.head()
df.iloc[0:6,0:4]  #first 5 rows and first 3 columns
df.shape
# Out:
# (234, 17)

# %%
df.set_index("Country/Territory",inplace=True) #making country/territory as index
df.head()
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country/Territory
# Afghanistan          36  AFG             Kabul      Asia         41128771
# Albania             138  ALB            Tirana    Europe          2842321
# Algeria              34  DZA           Algiers    Africa         44903225
# American Samoa      213  ASM         Pago Pago   Oceania            44273
# Andorra             203  AND  Andorra la Vella    Europe            79824
#
#                    2020 Population  2015 Population  2010 Population  \
# Country/Territory
# Afghanistan               38972230         33753499         28189672
# Albania                    2866849          2882481          2913399
# Algeria                   43451666         39543154         35856344
# American Samoa               46189            51368            54849
# Andorra                      77700            71746            71519
#
# ...

# %%
df.set_index("Rank", inplace=True) #making rank as index
df.sort_index(inplace=True, ascending=True) #sorting index
df.head()
#want to check type
df.index.dtype  # dtype of the index 
data=df["CCA3"].dtype  # dtype of the column
print(data)
# Out:
# object

# %%
df.loc[4]  #data of india
data = df.iloc[3]
data.head()
# Out:
# CCA3                     IDN
# Capital              Jakarta
# Continent               Asia
# 2022 Population    275501339
# 2020 Population    271857970
# Name: 4, dtype: object

# %%
data = df.groupby(["Capital"]) #extracting data of capital
data.size() #size of the data
# Out:
# Capital
# Abu Dhabi       1
# Abuja           1
# Accra           1
# Addis Ababa     1
# Algiers         1
#                ..
# Yamoussoukro    1
# Yaounde         1
# Yaren           1
# Yerevan         1
# Zagreb          1
# Length: 234, dtype: int64

# %%
data = df[["CCA3","Capital","Continent"]]  #extracting specific columns
data.iloc[0:5]  #first 5 rows of specific columns
# Out:
#      CCA3           Capital      Continent
# Rank
# 1     CHN           Beijing           Asia
# 2     IND         New Delhi           Asia
# 3     USA  Washington, D.C.  North America
# 4     IDN           Jakarta           Asia
# 5     PAK         Islamabad           Asia

# %%
d1 =df.sort_values(by= "2022 Population", ascending=True)  #sorting by population in descending order
d1.tail()
# Out:
#      CCA3           Capital      Continent  2022 Population  2020 Population  \
# Rank
# 5     PAK         Islamabad           Asia        235824862        227196741
# 4     IDN           Jakarta           Asia        275501339        271857970
# 3     USA  Washington, D.C.  North America        338289857        335942003
# 2     IND         New Delhi           Asia       1417173173       1396387127
# 1     CHN           Beijing           Asia       1425887337       1424929781
#
#       2015 Population  2010 Population  2000 Population  1990 Population  \
# Rank
# 5           210969298        194454498        154369924        115414069
# 4           259091970        244016173        214072421        182159874
# 3           324607776        311182845        282398554        248083732
# 2          1322866505       1240613620       1059633675        870452165
# 1          1393715448       1348191368       1264099069       1153704252
#
# ...

# %%
#df.set_index("CCA3", inplace=True,)
df.sort_index(inplace=True, ascending=True)
df.head()
#hello
# Out:
#          Capital      Continent  2022 Population  2020 Population  \
# CCA3
# ABW   Oranjestad  North America           106445           106585
# AFG        Kabul           Asia         41128771         38972230
# AGO       Luanda         Africa         35588987         33428485
# AIA   The Valley  North America            15857            15585
# ALB       Tirana         Europe          2842321          2866849
#
#       2015 Population  2010 Population  2000 Population  1990 Population  \
# CCA3
# ABW            104257           100341            89101            65712
# AFG          33753499         28189672         19542982         10694796
# AGO          28127721         23364185         16394062         11828638
# AIA             14525            13172            11047             8316
# ALB           2882481          2913399          3182021          3295066
#
#       1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# CCA3
# ...
